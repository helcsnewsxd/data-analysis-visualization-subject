# %% [markdown]
# # **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Edición 2024**
#
# ---
#
# # Varias Variables

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

#seaborn.set_context('talk')

# %% [markdown]
# ## Lectura del dataset
#
# En la notebook 00 se explican los detalles de la siguiente sección.

# %%
url ='https://raw.githubusercontent.com/DiploDatos/AnalisisyVisualizacion/master/sysarmy_survey_2023_processed.csv'
df = pd.read_csv(url)

# %%
df[:3]
# Out:
#   work_country work_province work_dedication         work_contract_type  \
# 0    Argentina     Catamarca       Full-Time  Staff (planta permanente)
# 1    Argentina     Catamarca       Full-Time  Staff (planta permanente)
# 2    Argentina     Catamarca       Full-Time  Staff (planta permanente)
#
#    salary_monthly_BRUTO  salary_monthly_NETO salary_in_usd  \
# 0              680000.0             520000.0           NaN
# 1              650000.0             520000.0           NaN
# 2              125000.0             104000.0           NaN
#
#   salary_last_dollar_value salary_has_bonus salary_bonus_tied_to  ...  \
# 0                      NaN               No       No recibo bono  ...
# 1                      NaN               No       No recibo bono  ...
# 2                      NaN               No       No recibo bono  ...
#
#   profile_studies_level_state                           profile_career  \
# 0                         NaN                                      NaN
# 1                    Completo  Licenciatura en Sistemas de Información
# 2                         NaN                                      NaN
#
#   Institución educativa  ¿Salir o seguir contestando sobre las guardias?  \
# 0                   NaN                                              NaN
# 1  Universidad Siglo 21                                Terminar encuesta
# 2                   NaN                                              NaN
#
#   work_on_call_duty  salary_on_call_duty_charge  \
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
#
#   Aclará el número que ingresaste en el campo anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ¿Salir o seguir contestando sobre estudios?  profile_age  profile_gender
# 0                                          NaN           36       Varón Cis
# 1                                          NaN           45       Varón Cis
# 2                                          NaN           29       Mujer Cis
#
# [3 rows x 43 columns]

# %% [markdown]
# # Variables Categóricas

# %% [markdown]
# Hay algunas variables que han sido rellenadas con texto, que hay que interpretar o son inútiles. En el 2022, la variable género tenia varias categorías que podían ser unidas en varon_cis o mujer_cis y diversidades. En el 2023, explotó el trolleo y el resultado es absurdo

# %%
df.profile_gender.unique()
# Out:
# array(['Varón Cis', 'Mujer Cis', 'Hombre', 'Prefiero no decir', 'normal',
#        'Varon', 'Agénero', 'Masculino', 'Dolarsexual', '.', 'Queer',
#        'Mujer Trans', 'No binarie',
#        'BIEN MACHO Y PORONGUDO. QUE CLASE DE OPCIONES DE MIERDA SON ESTAS?',
#        'no entiendo por que la hacen tan dificil. que es eso de cis? soy heterosexual.',
#        'Hombre..... tipo normal', 'Cis', 'varon, no se que es varon cis',
#        'Dejen de preguntar boludeces', 'Normal', 'que pelotudos eh',
#        'hombre', 'Helicoptero de ataque apache', 'Varón Trans',
#        'Varoo natural', 'Varón', 'Bigénero', 'Mujer', 'Transformer',
#        'Fluido', 'masculino', 'Hombre, macho silencioso', 'varón',
#        'no compliquemos lo simple', 'Agenero, presentación mujer cis',
#        'Me considero perteneciente al genero de los que no se identifican con ningun genero',
#        'Macho', 'Porque tantas opciones? Solo hay 2. Soy hombre.',
#        'heterosexual', 'Machote', 'Puto', 'Gris', 'Heterosexual',
#        'Hombre    (sexo cromosómico:  XY)',
#        'yo que se que es todo eso masculino',
#        'Insisto, no es tan complicado. ',
#        'No corresponde, es como preguntar la religion o el color de piel',
#        'No entiendo', 'no entiendo ni mierda q es cada una',
#        'Que? Fluido obvio', 'Lesbiana', 'Reptiliano',
#        'Que trolo sos para poner esas opciones', 'Hombre heterosexual',
#        'HETERO', 'mujer', 'Varon heterosexual', 'Hombre normal',
#        'mujer de cuando solo existian hombres y mujeres :oP',
#        'Varón Cis, pero considero ofensivo el término y esta pregunta.',
#        'no entiendo esas clasificaciones', 'HOMBRE', 'Varón común',
#        'soy un pollo', 'Hombre Heterosexual',
#        'me identifico con el eter de alfa centauri en venus con papas',
#        'Hombre Hetero', 'iddqd', 'Perro',
#        'heterosexual, pedazos de transtornados... ', 'Hombre Normal',
#        'varon', 'Tantas opciones que no supe qué elegir',
#        'Hombre. Varon.', 'Helicóptero', 'hetero',
#        'Sin enfermedades psiquiatricas', 'helicoptero apache',
#        'Hombre. Nada de pelotudeces.', 'soy mujer', 'que pelotudez',
#        'Soy hombre, el resto no se que significa',
#        'Soy una paleta de Carne',
#        'Que ganas de joder. Hombre heterosexual.', 'Usen castellano...',
#        'Masculino, Hombre, no encontré la opción correcta',
#        'que dificil esta pregunta',
#        'Es hombre o mujer, no caigan en esta pavada',
#        'No deberia ser obligatorio esto', 'Dolphin', 'marika',
#        'Hombre con pene',
#        'Varon macho pecho peludo, dejen de agregar tantas opciones lgbtq+qweasdw3',
#        'Esto es una boludes de pregunta. (En la universidad tambien la hacen)',
#        'MASCULINO', 'hombre varon',
#        'HOMBRE. nada de varon cis ni esas pelotudeces', 'Varon no Cis',
#        'un muchacho simple',
#        'Me molestan estas estupideces soy Mujer de nacimiento.',
#        'Hombre, no tengo ni idea que quiere decir cad aúna de las anteriores opciones ',
#        'Si caigo al hospital con perdida de conocimiento, me van a tratar como lo que soy... Hombre',
#        'hombre de hombre porque soy hombre', 'en serio?',
#        'Hombre de verdad', 'Que carajo son todas esos géneros. Hombre.',
#        'Soy hombre',
#        'Varon (tiene que estar como opción, no dar por asumido nada)',
#        'Esto es una boludez', 'Mujer (nada de cis)', 'No se q elegir',
#        'macho machista respetuoso de todes les demas', 'cis', 'Hétero',
#        'Hombre a secas', 'Varón hetero', 'Tractor multi punto',
#        'que pelotudes...', 'varon bi', 'Que boludez es esto',
#        'Pregunto, ¿Qué tiene que ver esto con la temática de la encuesta?',
#        'no se que poner',
#        'me identifico con todos, con el ser humano, soy heterosexual',
#        'hombre clasico', 'arstotzko', 'varon normal', 'Camionero',
#        'Hombre)?', 'Otaku', 'Humano', 'Soy Hombre.', 'Normal :)',
#        'Hombre Varón', 'Es broma verdad?', 'no es relevante',
#        'Varon sin utero', 'Basta', 'Hetero', 'Hiperpiturro',
#        'Varon, sin mas', 'Pokemón', 'Pelutudeces NO',
#        'Mujer NB (consejo, quizá podrían hacer un refactor de esta pregunta permitiendo muchas respuestas, así elegiría mujer, NB y trans, mientras que un hombre cis elegiría hombre y cis, sé que no todos en la comunidad IT se toman esto seriamente pero es más correcto y fiel a las experiencias de las personas)',
#        'Varón Cis No binario'], dtype=object)

# %%
df.loc[:,'profile_g'] = df.profile_gender.replace({'Varón Cis': 'Varón cis','Mujer': 'Mujer cis','Mujer Cis': 'Mujer cis','Femenino': 'Mujer cis','mujer': 'Mujer cis','Mujer':'Mujer cis','Queer':'Diversidades','Varón Trans':'Diversidades','No binarie':'Diversidades','Mujer Trans':'Diversidades','Fluido':'Diversidades','Bigénero':'Diversidades','Gay':'Diversidades'}).fillna(False)

# %%
salary_col = 'salary_monthly_NETO'

filtered_df= df[df[salary_col] < 2000000]
df_H= filtered_df[ filtered_df['profile_g']=='Varón cis']
df_M=filtered_df[ filtered_df['profile_g']=='Mujer cis']

# %%
sorted_studies_levels = ['Secundario', 'Terciario', 'Universitario',
                         'Maestría','Posgrado/Especialización', 'Doctorado', 'Posdoctorado']#lista de los nombres de categorías ordenadas
fig, axes = plt.subplots(ncols=2, figsize=(15,6)) #se genera la figura, se divide en dos lugares y se define su tamaño
g = seaborn.countplot(x= df.profile_studies_level.dropna(), color='steelblue', ax=axes[0]) #gráfico de conteos (en el lugar 0)
g = seaborn.countplot(x= df.profile_studies_level.dropna(), color='steelblue', ax=axes[1], #gráfico de conteos ordenado (en el lugar 1)
                  order=sorted_studies_levels)
for ax in axes:
  ax.tick_params(labelrotation=30) # en cada lugar (ax in axes) se rota la etiqueta

# %%
# Graficar la distribución de estudios por género
fig, axes = plt.subplots(ncols=2, figsize=(15,6), sharey=True)

seaborn.countplot(x= df_H.profile_studies_level.dropna(), color='steelblue', ax=axes[0], order=sorted_studies_levels)
seaborn.countplot(x= df_M.profile_studies_level.dropna(), color='lightpink', ax=axes[1], order=sorted_studies_levels)

for ax in axes:
  ax.tick_params(labelrotation=90)

plt.show()

# %% [markdown]
# # Variables Numéricas

# %%
salary_col='salary_monthly_BRUTO' #defino variable con el nombre de la columna de interés
#salary_col='salary_monthly_NETO'

# %%
fig, axes = plt.subplots(nrows=2, figsize=(14, 10)) #se genera la figura, se divide en dos lugares y se define su tamaño

seaborn.histplot(df[salary_col], bins=100, ax=axes[0], color='gray') #Histograma con 100 bins
axes[0].axvline(df[salary_col].mean(), color='orangered',
            linestyle='--', label='Media')
axes[0].axvline(df[salary_col].median(), color='indigo',
            linestyle='-.', label='Mediana')

filtered_df = df[df[salary_col] < 2_000_000]
seaborn.histplot(filtered_df[salary_col], bins=30, ax=axes[1], color='gray')
axes[1].axvline(filtered_df[salary_col].mean(), color='orangered',
            linestyle='--', label='Media')
axes[1].axvline(filtered_df[salary_col].median(), color='indigo',
            linestyle='-.', label='Mediana')

axes[0].legend()
seaborn.despine()

# %%
print(df[salary_col][:4])
print(type(df[salary_col]))
# Out:
# 0    680000.0
# 1    650000.0
# 2    125000.0
# 3    190000.0
# Name: salary_monthly_BRUTO, dtype: float64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Varias Variables

# %% [markdown]
# ## Varias Categóricas

# %%
## Tabla de contingencia
pd.crosstab(df.work_province, df.profile_studies_level)#, normalize=True) #no están ordenados
pd.crosstab(df.work_province, df.profile_studies_level)[sorted_studies_levels]#ordenados
# Out:
# profile_studies_level            Secundario  Terciario  Universitario  \
# work_province
# Catamarca                                 0          0              0
# Chaco                                     1          2             17
# Chubut                                    2          2             12
# Ciudad Autónoma de Buenos Aires          57        208            840
# Corrientes                                0          2             21
# Córdoba                                  12         40            172
# Entre Ríos                                1          2             21
# Formosa                                   0          0              0
# Jujuy                                     0          0              7
# La Pampa                                  2          1              4
# La Rioja                                  1          0              7
# Mendoza                                   2         19             51
# Misiones                                  1          6             10
# Neuquén                                   2          4              8
# Provincia de Buenos Aires                28        100            390
# Río Negro                                 1          4             14
# Salta                                     0          4             11
# San Juan                                  1          1             11
# San Luis                                  0          5              9
# Santa Cruz                                0          2              3
# Santa Fe                                  4         34            112
# Santiago del Estero                       0          1              8
# Tierra del Fuego                          0          0              2
# Tucumán                                   3          5             20
#
# profile_studies_level            Maestría  Posgrado/Especialización  \
# work_province
# Catamarca                               1                         0
# Chaco                                   1                         1
# Chubut                                  0                         0
# Ciudad Autónoma de Buenos Aires        63                        76
# Corrientes                              1                         1
# Córdoba                                11                        15
# Entre Ríos                              3                         1
# Formosa                                 0                         1
# Jujuy                                   0                         2
# La Pampa                                0                         0
# La Rioja                                0                         2
# Mendoza                                 9                         4
# Misiones                                2                         1
# Neuquén                                 0                         4
# Provincia de Buenos Aires              21                        28
# Río Negro                               0                         1
# Salta                                   0                         1
# San Juan                                0                         0
# San Luis                                1                         0
# Santa Cruz                              0                         1
# Santa Fe                                1                        11
# Santiago del Estero                     0                         0
# Tierra del Fuego                        0                         0
# Tucumán                                 2                         1
#
# profile_studies_level            Doctorado  Posdoctorado
# work_province
# Catamarca                                0             0
# Chaco                                    0             0
# Chubut                                   1             0
# Ciudad Autónoma de Buenos Aires         13             2
# Corrientes                               0             0
# Córdoba                                  6             1
# Entre Ríos                               0             0
# Formosa                                  0             0
# Jujuy                                    0             0
# La Pampa                                 0             0
# La Rioja                                 0             0
# Mendoza                                  2             0
# Misiones                                 0             0
# Neuquén                                  0             0
# Provincia de Buenos Aires                3             5
# Río Negro                                1             0
# Salta                                    0             0
# San Juan                                 0             0
# San Luis                                 0             0
# Santa Cruz                               0             0
# Santa Fe                                 2             0
# Santiago del Estero                      0             0
# Tierra del Fuego                         0             0
# Tucumán                                  0             0

# %%
fig = plt.figure(figsize=(6,4))
exp = pd.crosstab(df.work_province,
                  df.profile_studies_level)[sorted_studies_levels]
seaborn.heatmap(exp, annot=True, fmt='g')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
seaborn.despine()

# %%
## Tabla de contingencia normalizada, la suma de los valores da 1, son proporciones, estima probabilidad
pd.crosstab(df.profile_age, df.profile_studies_level, normalize=True)[sorted_studies_levels]
# Out:
# profile_studies_level  Secundario  Terciario  Universitario  Maestría  \
# profile_age
# 18                       0.000383   0.000000       0.000000  0.000000
# 19                       0.000383   0.000383       0.002296  0.000000
# 20                       0.001148   0.000765       0.003827  0.000000
# 21                       0.000765   0.001914       0.007654  0.000000
# 22                       0.001914   0.003827       0.018752  0.000000
# 23                       0.001531   0.004975       0.024493  0.000000
# 24                       0.001531   0.006889       0.030616  0.000765
# 25                       0.002296   0.006889       0.037122  0.001148
# 26                       0.001914   0.008419       0.037887  0.001148
# 27                       0.001148   0.011481       0.046307  0.000765
# 28                       0.002679   0.008802       0.041715  0.000765
# 29                       0.002296   0.008419       0.031382  0.000765
# 30                       0.004975   0.006506       0.036739  0.003827
# 31                       0.002296   0.008802       0.035209  0.002679
# 32                       0.001531   0.008802       0.034443  0.001531
# 33                       0.001531   0.009185       0.025258  0.000765
# 34                       0.001148   0.007654       0.029851  0.001914
# 35                       0.002679   0.009185       0.023345  0.003062
# 36                       0.001148   0.005741       0.022579  0.002679
# 37                       0.001531   0.004975       0.019518  0.000383
# 38                       0.001531   0.004975       0.023345  0.000000
# 39                       0.001531   0.006506       0.017987  0.003062
# 40                       0.001148   0.001531       0.018370  0.000383
# 41                       0.001148   0.003827       0.012629  0.000765
# 42                       0.001914   0.003827       0.012629  0.002679
# 43                       0.000000   0.005741       0.009950  0.000765
# 44                       0.000383   0.002679       0.009950  0.000765
# 45                       0.001148   0.002679       0.009568  0.003444
# 46                       0.000765   0.003444       0.008419  0.000765
# 47                       0.000383   0.001531       0.007271  0.002679
# 48                       0.000000   0.001531       0.006123  0.000765
# 49                       0.000000   0.000765       0.004210  0.000765
# 50                       0.000000   0.002296       0.004592  0.001148
# 51                       0.000000   0.000383       0.002296  0.000765
# 52                       0.000000   0.000000       0.001148  0.000000
# 53                       0.000000   0.001148       0.003062  0.000765
# 54                       0.000000   0.000000       0.001531  0.000383
# 55                       0.000000   0.000383       0.001914  0.000000
# 56                       0.000000   0.000383       0.001531  0.000383
# 57                       0.000000   0.001148       0.001148  0.000000
# 58                       0.000000   0.000383       0.000765  0.000383
# 59                       0.000383   0.000000       0.000000  0.000000
# 60                       0.000000   0.000000       0.001148  0.000000
# 62                       0.000000   0.000383       0.000000  0.000383
# 63                       0.000000   0.000000       0.000765  0.000000
# 64                       0.000000   0.000000       0.000000  0.000000
# 66                       0.000000   0.000000       0.000000  0.000383
# 68                       0.000000   0.000000       0.000000  0.000383
# 70                       0.000000   0.000000       0.000000  0.000383
# 75                       0.000000   0.000000       0.000000  0.000000
# 100                      0.000000   0.000000       0.000383  0.000000
#
# profile_studies_level  Posgrado/Especialización  Doctorado  Posdoctorado
# profile_age
# 18                                     0.000383   0.000000      0.000000
# 19                                     0.000000   0.000000      0.000000
# 20                                     0.000000   0.000000      0.000000
# 21                                     0.000000   0.000000      0.000000
# 22                                     0.000000   0.000000      0.000000
# 23                                     0.000000   0.000000      0.000000
# 24                                     0.000765   0.000000      0.000000
# 25                                     0.000383   0.000383      0.000000
# 26                                     0.000765   0.000000      0.000000
# 27                                     0.001148   0.000765      0.000000
# 28                                     0.001148   0.000000      0.000000
# 29                                     0.002296   0.000383      0.000000
# 30                                     0.002296   0.000000      0.000000
# 31                                     0.002679   0.000383      0.000383
# 32                                     0.003827   0.000765      0.000000
# 33                                     0.001914   0.001148      0.000000
# 34                                     0.001914   0.000383      0.000000
# 35                                     0.001914   0.001148      0.000000
# 36                                     0.003062   0.000765      0.000000
# 37                                     0.001531   0.000383      0.000383
# 38                                     0.002296   0.000000      0.000383
# 39                                     0.002296   0.000383      0.000383
# 40                                     0.002679   0.000765      0.000383
# 41                                     0.003062   0.000383      0.000383
# 42                                     0.002679   0.000765      0.000000
# 43                                     0.001914   0.000000      0.000383
# 44                                     0.003062   0.000383      0.000383
# 45                                     0.001148   0.000000      0.000000
# 46                                     0.002679   0.000000      0.000000
# 47                                     0.000383   0.000383      0.000000
# 48                                     0.001914   0.000000      0.000000
# 49                                     0.001531   0.000383      0.000000
# 50                                     0.001914   0.000383      0.000000
# 51                                     0.000000   0.000000      0.000000
# 52                                     0.000383   0.000000      0.000000
# 53                                     0.000765   0.000000      0.000000
# 54                                     0.000765   0.000000      0.000000
# 55                                     0.000383   0.000383      0.000000
# 56                                     0.000000   0.000000      0.000000
# 57                                     0.000383   0.000000      0.000000
# 58                                     0.000383   0.000000      0.000000
# 59                                     0.000383   0.000000      0.000000
# 60                                     0.000000   0.000000      0.000000
# 62                                     0.000000   0.000000      0.000000
# 63                                     0.000000   0.000000      0.000000
# 64                                     0.000383   0.000000      0.000000
# 66                                     0.000000   0.000000      0.000000
# 68                                     0.000000   0.000000      0.000000
# 70                                     0.000000   0.000000      0.000000
# 75                                     0.000383   0.000000      0.000000
# 100                                    0.000000   0.000000      0.000000

# %%
fig = plt.figure(figsize=(8,4))
seaborn.countplot(x= df[df['profile_age'] < 80].profile_studies_level,  hue=df.profile_age.dropna()[df['profile_age'] < 80], order=sorted_studies_levels )
plt.xticks(rotation=40)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Secundario'),
#   Text(1, 0, 'Terciario'),
#   Text(2, 0, 'Universitario'),
#   Text(3, 0, 'Maestría'),
#   Text(4, 0, 'Posgrado/Especialización'),
#   Text(5, 0, 'Doctorado'),
#   Text(6, 0, 'Posdoctorado')])

# %% [markdown]
# ## Varias numéricas

# %%
max_sal = 2_000_000
df2 = df.loc[(df['salary_monthly_NETO'] < max_sal) & (df['profile_age'] < 80) & (df['salary_monthly_BRUTO'] < max_sal)]
seaborn.pairplot(data=df2,
                 y_vars=['profile_age', 'salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO', 'salary_monthly_BRUTO'],
                 aspect=2, height=3)

# %%
fig = plt.figure(figsize=(8,4))
seaborn.jointplot(data=df2, x='salary_monthly_NETO',
                  y='profile_age', kind='hex', height=6)
plt.axvline(df2['salary_monthly_NETO'].mean(), color='orangered',
            linestyle='--', label='Media Salario')
plt.axhline(df2['profile_age'].mean(), color='blue',
            linestyle='--', label='Media Edad')
plt.legend()
plt.colorbar()
# Remove scietific notation
plt.ticklabel_format(style='plain', axis='y')

# %%
seaborn.jointplot(data=df2, x='salary_monthly_NETO',
                  y='profile_age', kind='kde', height=6)
# Remove scietific notation
plt.ticklabel_format(style='plain', axis='y')

# %%
seaborn.pairplot(data=df2, y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)

# %% [markdown]
# **Pregunta** ¿Cuáles le parece que son las ventajas de ver de a dos  (o más) variables simultáneamente? $\rightarrow$ Podés evaluar la dependencia

# %% [markdown]
# ## Mixtas

# %%
filtered_df= df[df[salary_col] < 2000000] #mirar como cambia filtrando por valores menores...
df_H= filtered_df[ filtered_df['profile_g']=='Varón cis']
df_M=filtered_df[ filtered_df['profile_g']=='Mujer cis']

plt.hist(df_H[salary_col], color='orangered', bins=50)
plt.hist(df_M[salary_col], color='steelblue', bins=50) #aca importa el orden, cuidado con la superposición
plt.show()

# %%
max_age=99
seaborn.pairplot(data=df[df.profile_age < max_age], y_vars=['salary_monthly_NETO'],
                 x_vars=['salary_satisfaction'],
                 aspect=2, height=4)

# %% [markdown]
# Una desventaja de usar un pairplot para variables categóricas es la superposición de los puntos que tienen el mismo valor. Un gráfico que soluciona este problema es el `catplot`

# %%
seaborn.catplot(data=df[df.salary_monthly_NETO < max_sal], y='salary_monthly_NETO',  #probar también con profile_age, 'profile_gender'
                x='salary_satisfaction', height=4, aspect=2)

# %%
seaborn.jointplot(data=df[df.salary_monthly_NETO < max_sal], x='profile_age',
                  y='salary_monthly_NETO', hue='profile_studies_level',
                  kind='kde', height=8)

# %% [markdown]
# Distribucion (con boxplot) condicional

# %%
plt.figure(figsize=(12, 6))
seaborn.boxplot(data=df, x=salary_col, y='profile_studies_level',
                color='orangered')
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# # Práctico para resolver en clase
#
# 1. Analice las variables `'salary_monthly_BRUTO'` (salario mensual Bruto) y `'salary_monthly_NETO'` (salario Neto) en conjunto, que comentarios puede hacer al respecto?

# %%
import numpy as np
df_limpio=df[(df.salary_monthly_BRUTO <1500000)& (df.salary_monthly_NETO <1500000)]
seaborn.pairplot(data=df_limpio, y_vars=['salary_monthly_BRUTO'],
                 x_vars=['salary_monthly_NETO'],
                 aspect=2, height=4)
plt.xticks(rotation=20)
# Out:
# (array([-200000.,       0.,  200000.,  400000.,  600000.,  800000.,
#         1000000., 1200000., 1400000., 1600000.]),
#  [Text(-200000.0, 0, '−0.2'),
#   Text(0.0, 0, '0.0'),
#   Text(200000.0, 0, '0.2'),
#   Text(400000.0, 0, '0.4'),
#   Text(600000.0, 0, '0.6'),
#   Text(800000.0, 0, '0.8'),
#   Text(1000000.0, 0, '1.0'),
#   Text(1200000.0, 0, '1.2'),
#   Text(1400000.0, 0, '1.4'),
#   Text(1600000.0, 0, '1.6')])

# %% [markdown]
# 2. Generamos una nueva columna `'salary_monthly_DESCUENTOS'= 'salary_monthly_BRUTO'-'salary_monthly_NETO'`, es decir que contenga los descuentos mensuales.
# 3. Analice la distribución de esta columna de datos gráficamente.

# %%
df_limpio['salary_monthly_DESCUENTOS']=df_limpio.salary_monthly_BRUTO-df_limpio.salary_monthly_NETO #generamos una nueva columna
#print(df_limpio.loc[0:2,'salary_monthly_BRUTO']), print(df_limpio.loc[0:2,'salary_monthly_NETO'])
#print(df_limpio['salary_monthly_DESCUENTOS'][0:2])
df_limpio[0:3] #mire la última columna
# Out:
# C:\Users\emanu\AppData\Local\Temp\ipykernel_24136\4041930682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['salary_monthly_DESCUENTOS']=df_limpio.salary_monthly_BRUTO-df_limpio.salary_monthly_NETO #generamos una nueva columna
#   work_country work_province work_dedication         work_contract_type  \
# 0    Argentina     Catamarca       Full-Time  Staff (planta permanente)
# 1    Argentina     Catamarca       Full-Time  Staff (planta permanente)
# 2    Argentina     Catamarca       Full-Time  Staff (planta permanente)
#
#    salary_monthly_BRUTO  salary_monthly_NETO salary_in_usd  \
# 0              680000.0             520000.0           NaN
# 1              650000.0             520000.0           NaN
# 2              125000.0             104000.0           NaN
#
#   salary_last_dollar_value salary_has_bonus salary_bonus_tied_to  ...  \
# 0                      NaN               No       No recibo bono  ...
# 1                      NaN               No       No recibo bono  ...
# 2                      NaN               No       No recibo bono  ...
#
#   Institución educativa  ¿Salir o seguir contestando sobre las guardias?  \
# 0                   NaN                                              NaN
# 1  Universidad Siglo 21                                Terminar encuesta
# 2                   NaN                                              NaN
#
#   work_on_call_duty  salary_on_call_duty_charge  \
# 0               NaN                         NaN
# 1               NaN                         NaN
# 2               NaN                         NaN
#
#   Aclará el número que ingresaste en el campo anterior  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    ¿Salir o seguir contestando sobre estudios? profile_age  profile_gender  \
# 0                                          NaN          36       Varón Cis
# 1                                          NaN          45       Varón Cis
# 2                                          NaN          29       Mujer Cis
#
#    profile_g  salary_monthly_DESCUENTOS
# 0  Varón cis                   160000.0
# 1  Varón cis                   130000.0
# 2  Mujer cis                    21000.0
#
# [3 rows x 45 columns]

# %%
df_limpio['salary_monthly_DESCUENTOS'].mean()
# Out:
# 106054.49348340217

# %%
df_limpio['salary_monthly_DESCUENTOS'].min()
# Out:
# -1108000.0

# %%
seaborn.histplot(df_limpio['salary_monthly_DESCUENTOS'])
# Out:
# <Axes: xlabel='salary_monthly_DESCUENTOS', ylabel='Count'>

# %% [markdown]
# Interpretemos correlación entre las columnas de sueldos
#
# -Calcular las medias (ambas columnas)
#
# -Hacer el grafico que corresponda

# %%
matcov=np.cov(df_limpio.salary_monthly_BRUTO,df_limpio.salary_monthly_NETO)
print('matriz de varianza covarianza:','\n',matcov,'\n')

corr=np.corrcoef(df_limpio.salary_monthly_BRUTO,df_limpio.salary_monthly_NETO)
print('matriz de correlaciones: \n ', corr,'\n')

print('correlación entra ambas variables: ',corr[0,1],'\n')

# df_limpio.salary_monthly_BRUTO.describe().apply(lambda s: '{0:.2f}'.format(s))
# df_limpio.salary_monthly_NETO.describe().apply(lambda s: '{0:.2f}'.format(s))
# Out:
# matriz de varianza covarianza:
#  [[1.04426834e+11 7.21087320e+10]
#  [7.21087320e+10 6.17617624e+10]]
#
# matriz de correlaciones:
#   [[1.         0.89788758]
#  [0.89788758 1.        ]]
#
# correlación entra ambas variables:  0.8978875762371107
